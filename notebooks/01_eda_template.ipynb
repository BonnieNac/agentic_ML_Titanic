# %% [markdown]
# # 📓 Exploratory Data Analysis Template
#
# Projet : **Titanic ML**

# %%
import matplotlib.pyplot as plt

from titanic_ml.core.data_io.loader import load_data

df = load_data()
df.head()

# %% [markdown]
# ## 1. Statistiques de base

# %%
df.describe(include="all")

# %% [markdown]
# ## 2. Visualisations

# %%
df["Survived"].value_counts().plot(kind="bar", title="Répartition des survivants")
plt.show()
